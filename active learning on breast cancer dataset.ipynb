# %%
#active learning on breast cancer dataset
import numpy as np
from scipy.stats import mode
from sklearn.datasets import load_breast_cancer
from numpy.random import randint

 
#Euclidean Distance
def eucledian(p1,p2):
    dist = np.sqrt(np.sum((p1-p2)**2))
    return dist
 
#Function to calculate KNN
def predict(x_train, y , x_input, k):
    op_labels = []
     
    #Loop through the Datapoints to be classified
    for item in x_input: 
         
        #Array to store distances
        point_dist = []
         
        #Loop through each training Data
        for j in range(len(x_train)): 
            distances = eucledian(np.array(x_train[j,:]) , item) 
            #Calculating the distance
            point_dist.append(distances) 
        point_dist = np.array(point_dist) 
         
        #Sorting the array while preserving the index
        #Keeping the first K datapoints
        dist = np.argsort(point_dist)[:k] 
         
        #Labels of the K datapoints from above
        labels = y[dist]
         
        #Majority voting
        lab = mode(labels) 
        lab = lab.mode[0]
        op_labels.append(lab)
 
    return op_labels
#function to calculate most ambiguas point
def ambiguas(x_train, y , x_input, k, w):
    op_labels = []
     
    #Loop through the Datapoints to be classified
    for item in x_input: 
         
        #Array to store distances
        point_dist = []
         
        #Loop through each training Data
        for j in range(len(x_train)): 
            distances = eucledian(np.array(x_train[j,:]) , item) 
            #Calculating the distance
            point_dist.append(distances) 
        point_dist = np.array(point_dist) 
         
        #Sorting the array while preserving the index
        #Keeping the first K datapoints
        dist = np.argsort(point_dist)[:k] 
        
         
        #Labels of the K datapoints from above
        labels = y[dist]
        
        #majority
        count0 = 0
        count1 = 0
        
        for i in range(k):
            if(labels[i] == 0):
                count0 = count0+1
            elif(labels[i] == 1):
                count1 = count1+1
            
         
        occur = [count0, count1]
        
        occur.sort(reverse = True)
    
        diff = (occur[0] - occur[1])/k
        
        #Majority voting
        #lab = mode(labels) 
        #lab1 = lab.mode[0]
        #lab3 = np.count_nonzero(labels == lab1)
        #neww = [i for i in kabels if i!= lab1]
        
        #lab5 = mode(neww)
        #lab2 = lab5.mode[0]
        
        #lab4 = np.count_nonzero(neww == lab2)
        #diff = (lab3 - lab4)/k
        
        op_labels.append(diff)
    op_labels = np.array(op_labels)
    
    j = np.argsort(op_labels)[:w]

    return j



def accu_scr(y_test, y_pred):
    cnt = 0
    for k in range(len(y_test)):
        if(y_pred[k] == y_test[k]):
            cnt = cnt+1
    p = cnt/len(y_test)
    
    return p
    


#Loading the Data
iris= load_breast_cancer()
 
# Store features matrix in X
X= iris.data


#Store target vector in 
y= iris.target



r = input("Specify the size of training dataset: ")
n = input("Specify the size of training dataset for active learn: ")
l = input("Specify the size of testing dataset: ")
z = input("Input the value of k: ")
u = 1

# k = input("Input the value of k for active learning: ")

counter = 0
for g in range(15):
    count = 0
    arr = []
    #Creating the training Data
    train_idx = []
    for p in range(2):
        if(p == 0):
            tt = xxx = randint(0 ,212 ,int(int(r)/2))
        if(p == 1):
            tt = xxx = randint(212 ,569 ,int(int(r)/2)) 
            
       
        for w in range(len(tt)):
            train_idx.append(tt[w]) 

    X_train = X[train_idx]

    y_train = y[train_idx]

    T = X.copy()
    S = y.copy()
    f = int((int(n))/int(u))
    index = []

    for b in range(f):
        index = np.array(index)
        index = ambiguas(X_train,y_train,T , int(z), int(u))
        
        X_train = np.append(X_train, T[index]).reshape(1,(int(r)+int(u)*(b + 1))*30).reshape(int(r)+int(u)*(b + 1),30)
        y_train = np.append(y_train, S[index])
        
        
        
        
        
        
        
        
        
        
        T = np.delete(T, index, 0)
        S = np.delete(S, index)


    # indexes = ambiguas(X_train,y_train,X , int(k))
    # indexes = np.array(indexes)
    # print(indexes)



    # new_indexes = np.argsort(indexes)[:int(n)]

    # new_ind = new_indexes.tolist() + train_idx
    # print(new_ind)
    # X_t = X[new_ind]
    # y_t = y[new_ind]

    # print(y_t)

    # X_tr = X_train + X_t
    # y_tr = y_train + y_t


    # for s in range(int(n)):
    #     X_train.append(X_t[s])
    #     y_train.append(y_t[s])
    # # X_train = X[new_indexes]
    # # y_train = y[new_indexes]

    


        #Creating the testing Data
    test_idx = xxx = randint(0,569,int(l)) 
    X_test = X[test_idx]
    y_test = y[test_idx]



    #Applying the created function 
    y_pred = predict(X_train,y_train,X_test , int(z))
    #Checking the accuracy
    a = accu_scr(y_test, y_pred)
    #keeping the value in an array
    arr.append(a)

    print("Accuracy for testcase ", g+1 ,"is: ", a*100, "%" )

    #calculating mean accuracy

    
     
    counter = counter + a
#     print("\nAccuracy for iteration ", g ,"is: ", (counter/*100,"%\n") 
    
overall_mean = counter/15
print("Overall mean is: ", overall_mean*100,"%")
# Out:
# Specify the size of training dataset: 6
# Specify the size of training dataset for active learn: 20
# Specify the size of testing dataset: 500
# Input the value of k: 4
# Accuracy for testcase  1 is:  90.2 %
# Accuracy for testcase  2 is:  91.8 %
# Accuracy for testcase  3 is:  93.0 %
# Accuracy for testcase  4 is:  93.0 %
# Accuracy for testcase  5 is:  91.4 %
# Accuracy for testcase  6 is:  94.6 %
# Accuracy for testcase  7 is:  93.4 %
# Accuracy for testcase  8 is:  92.2 %
# Accuracy for testcase  9 is:  91.4 %
# Accuracy for testcase  10 is:  89.8 %
# Accuracy for testcase  11 is:  91.0 %
# Accuracy for testcase  12 is:  91.4 %
# Accuracy for testcase  13 is:  92.80000000000001 %
# Accuracy for testcase  14 is:  90.60000000000001 %
# Accuracy for testcase  15 is:  89.8 %
# Overall mean is:  91.76 %
